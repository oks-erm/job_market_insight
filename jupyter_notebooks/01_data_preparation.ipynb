# %% [markdown]
# Retrieve job data from a PostgreSQL database and sort by date.

# %%
import psycopg2
import pandas as pd
from urllib import parse
import os
import sys

# Add the path to the folder containing the env.py
sys.path.append('../')
from env import *

DATABASE_URL = os.environ['DATABASE_URL']
parse.uses_netloc.append('postgres')
url = parse.urlparse(DATABASE_URL)
DB_HOST = url.hostname
DB_PORT = url.port
DB_NAME = url.path[1:]
DB_USER = url.username
DB_PASSWORD = url.password

conn = psycopg2.connect(host=DB_HOST, port=DB_PORT,
                        database=DB_NAME, user=DB_USER, password=DB_PASSWORD)

cur = conn.cursor()

cur.execute(
    '''
        SELECT j.job_id, j.title, j.company, l.location_name as location, c.category_name as category, j.date, j.skills, j.link
        FROM jobs j
        JOIN locations l ON j.location_id = l.id
        JOIN job_categories c ON j.category_id = c.id
        '''
)
job_data = cur.fetchall()

# create pandas DataFrame
df = pd.DataFrame(job_data, columns=[
                  "job_id", "title", "company", "location", "category", "date", "skills", "link"])

cur.close()
conn.close()

df_sorted = df.sort_values('date', ascending=False)

df_sorted
# Out:
#          job_id                                              title  \
# 293  3470051574                                    React Developer
# 325  3659406705           JavaScript / TypeScript Engineer (React)
# 429  2871444461                Software Engineer - React Developer
# 381  3654252929                         Frontend Software Engineer
# 68   3442085243                   Quant Engineer - Lisbon or Porto
# ..          ...                                                ...
# 318  3427792722                              Oferta: Web Developer
# 216  3427793485  Oferta de emprego: Consultor Júnior (M/F) – Co...
# 479  3103152307                                   NodeJs Developer
# 560  2650549046                                     UX/UI Designer
# 94   2650543918                                     Data Scientist
#
#                      company                  location  \
# 293                 Affinity  Lisbon, Lisbon, Portugal
# 325                Evolution  Lisboa, Lisbon, Portugal
# 429           GRiT Solutions    Porto, Porto, Portugal
# 381                    HiBob  Lisboa, Lisbon, Portugal
# 68           BNP Paribas CIB  Lisboa, Lisbon, Portugal
# ..                       ...                       ...
# 318                   KCS iT    Porto, Porto, Portugal
# 216  Oficina de Competências    Braga, Braga, Portugal
# 479         Smart Consulting           Porto, Portugal
# 560         Smart Consulting  Lisbon Metropolitan Area
# 94          Smart Consulting  Lisbon Metropolitan Area
#
#                                               category        date  \
# 293                       Serviços e consultoria de TI  2023-07-09
# 325                       Serviços e consultoria de TI  2023-07-09
# 429                       Serviços e consultoria de TI  2023-07-09
# 381  Desenvolvimento de software personalizado de s...  2023-07-09
# 68                                Serviços financeiros  2023-07-09
# ..                                                 ...         ...
# 318                       Serviços e consultoria de TI  2022-12-11
# 216                       Serviços de recursos humanos  2022-12-11
# 479                       Serviços e consultoria de TI  2022-07-26
# 560                       Serviços e consultoria de TI  2022-03-07
# 94                        Serviços e consultoria de TI  2022-03-07
#
#                                                 skills  \
# 293                                              React
# 325  React,Jest,Jenkins,Redux,Enzyme,iOS,Jira,JavaS...
# 429           React,Agile Methodology,CI/CD,JavaScript
# 381  React,Angular,Microservices Architecture,CSS,T...
# 68   C,Artificial Intelligence,DevOps,Go,JavaScript...
# ..                                                 ...
# 318                           Angular,React,JavaScript
# 216
# 479                                   Scrum,JavaScript
# 560                                      User Research
# 94                                 R,Java,Scala,Python
#
#                                                   link
# 293  https://pt.linkedin.com/jobs/view/react-develo...
# 325  https://pt.linkedin.com/jobs/view/javascript-t...
# 429  https://pt.linkedin.com/jobs/view/software-eng...
# 381  https://pt.linkedin.com/jobs/view/frontend-sof...
# 68   https://pt.linkedin.com/jobs/view/quant-engine...
# ..                                                 ...
# 318  https://pt.linkedin.com/jobs/view/oferta-web-d...
# 216  https://pt.linkedin.com/jobs/view/oferta-de-em...
# 479  https://pt.linkedin.com/jobs/view/nodejs-devel...
# 560  https://pt.linkedin.com/jobs/view/ux-ui-design...
# 94   https://pt.linkedin.com/jobs/view/data-scienti...
#
# [610 rows x 8 columns]

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# * Data profiling

# %%
import matplotlib.pyplot as plt
# View the first few rows of the DataFrame
df.head()

# Get summary statistics of the numeric columns
df.describe()

# Check the data types of each column
df.dtypes

# Check the number of missing values in each column
df.isnull().sum()
# Out:
# job_id      0
# title       0
# company     0
# location    0
# category    0
# date        0
# skills      0
# link        0
# dtype: int64

# %% [markdown]
# * Handle missing values

# %%
# Fill missing values with "N/A"
df_filled = df.fillna(value="N/A")

# %% [markdown]
# * Handle duplicates

# %%
# Drop duplicate rows
df.drop_duplicates()

# Count the number of duplicate rows
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * Prepare data for analysis (process date and location formats)

# %%
from geotext import GeoText


# Convert 'date' column to datetime
df['date'] = pd.to_datetime(df['date'])


def extract_place_names(location_str):
    places = GeoText(location_str)
    city = places.cities[0] if places.cities else ''
    country = places.countries[0] if places.countries else ''
    return city, country


df[['city', 'country']] = df['location'].apply(
    lambda x: pd.Series(extract_place_names(x)))
# Out:
#          job_id                                 title  \
# 0    3645811837                          Data Analyst
# 1    3654895534               Backend Engineer Python
# 2    3633677699  Senior Software Engineer - Python SE
# 3    3520146025              Django Backend Developer
# 4    3194940087            Software Engineer (Python)
# ..          ...                                   ...
# 605  3632315061                    Junior SW Engineer
# 606  3635280197         Senior Python Developer (m/f)
# 607  3638490397                     Backend Developer
# 608  3597476083                         Data Engineer
# 609  3654261004                    Software Developer
#
#                                    company                   location  \
# 0                                 Celfocus   Lisbon, Lisbon, Portugal
# 1                BytePitch - Software Labs     Porto, Porto, Portugal
# 2                          ComplyAdvantage   Lisboa, Lisbon, Portugal
# 3                                  Probely   Lisboa, Lisbon, Portugal
# 4                                  Revolut                   Portugal
# ..                                     ...                        ...
# 605                                  Nokia  Amadora, Lisbon, Portugal
# 606  AI4MedImaging- Medical Solutions S.A.     Braga, Braga, Portugal
# 607                         Robert Walters     Braga, Braga, Portugal
# 608                               RedCloud   Lisbon, Lisbon, Portugal
# 609                              Checkmarx   Lisbon Metropolitan Area
#
#                                               category       date  \
# 0                         Serviços e consultoria de TI 2023-06-30
# 1                    Tecnologia, Informação e Internet 2023-06-09
# 2                          Desenvolvimento de software 2023-07-03
# 3                    Segurança de redes e computadores 2023-03-09
# 4    Serviços e consultoria de TI, Desenvolvimento ... 2023-06-19
# ..                                                 ...        ...
# 605    Serviços e consultoria de TI e Telecomunicações 2023-07-07
# 606                 Fabricação de equipamentos médicos 2023-06-13
# 607                             Recrutamento e seleção 2023-06-19
# 608                        Desenvolvimento de software 2023-04-14
# 609                  Segurança de redes e computadores 2023-06-14
#
#                                                 skills  \
# 0    SQL,PHP,Artificial Intelligence,Grafana,Tablea...
# 1    Scrum,DevOps,Scala,Fintech,AWS,Data Engineerin...
# 2       Python,Kotlin,Natural Language Processing,Java
# 3    Cybersecurity,Security Testing,Django,Informat...
# 4    Data Pipelines,Docker,Django,Data Privacy,Ansi...
# ..                                                 ...
# 605  Python,Cloud Computing,C,Continuous Integratio...
# 606         Django,Flask,Python,Code Review,JavaScript
# 607   TypeScript,JavaScript,React Native,React,MongoDB
# 608    AWS,Data Security,Python,Data Pipelines,ETL,SQL
# 609                             CI/CD,Security Testing
#
#                                                   link     city   country
# 0    https://pt.linkedin.com/jobs/view/data-analyst...   Lisbon  Portugal
# 1    https://pt.linkedin.com/jobs/view/backend-engi...    Porto  Portugal
# 2    https://pt.linkedin.com/jobs/view/senior-softw...   Lisbon  Portugal
# 3    https://pt.linkedin.com/jobs/view/django-backe...   Lisbon  Portugal
# 4    https://pt.linkedin.com/jobs/view/software-eng...           Portugal
# ..                                                 ...      ...       ...
# 605  https://pt.linkedin.com/jobs/view/junior-sw-en...  Amadora  Portugal
# 606  https://pt.linkedin.com/jobs/view/senior-pytho...    Braga  Portugal
# 607  https://pt.linkedin.com/jobs/view/backend-deve...    Braga  Portugal
# 608  https://pt.linkedin.com/jobs/view/data-enginee...   Lisbon  Portugal
# 609  https://pt.linkedin.com/jobs/view/software-dev...
#
# [610 rows x 10 columns]

# %%
df.head(20)
# Out:
#         job_id                                             title  \
# 0   3645811837                                      Data Analyst
# 1   3654895534                           Backend Engineer Python
# 2   3633677699              Senior Software Engineer - Python SE
# 3   3520146025                          Django Backend Developer
# 4   3194940087                        Software Engineer (Python)
# 5   3652435372                           Senior Python Developer
# 6   3631040207                                  Python Developer
# 7   3194935635                        Software Engineer (Python)
# 8   3628051380                             team Python Developer
# 9   3493425989                          Data Scientist (Andorra)
# 10  3636285322                                  Python Developer
# 11  3658118152                 Senior Python Developer/Analytics
# 12  3646677150                                  Python Developer
# 13  3447196368                                  Python Developer
# 14  3636283390                                  Python Developer
# 15  3608268739   Senior Full-Stack Engineer Python/Data Engineer
# 16  3656916111                       Software Developer - Python
# 17  3636281917                                  Python Developer
# 18  3570801028  Python Engineer (Research & Development) (m/f/d)
# 19  3636286717                                  Python Developer
#
#                       company                        location  \
# 0                    Celfocus        Lisbon, Lisbon, Portugal
# 1   BytePitch - Software Labs          Porto, Porto, Portugal
# 2             ComplyAdvantage        Lisboa, Lisbon, Portugal
# 3                     Probely        Lisboa, Lisbon, Portugal
# 4                     Revolut                        Portugal
# 5       Core Tech Recruitment                Lisbon, Portugal
# 6                      Noesis        Lisboa, Lisbon, Portugal
# 7                     Revolut          Porto, Porto, Portugal
# 8                     team.it          Porto, Porto, Portugal
# 9             Gauss & Neumann        Lisbon, Lisbon, Portugal
# 10                    Mindpal          Porto, Porto, Portugal
# 11                     red.it                Lisbon, Portugal
# 12                  Neotalent        Lisboa, Lisbon, Portugal
# 13                      Ytech        Lisbon, Lisbon, Portugal
# 14                    Mindpal        Lisboa, Lisbon, Portugal
# 15                  Intellias                        Portugal
# 16           agap2IT Portugal        Lisboa, Lisbon, Portugal
# 17                    Mindpal       Amadora, Lisbon, Portugal
# 18                    Siemens       Amadora, Lisbon, Portugal
# 19                    Mindpal  Vila Nova, Vila Real, Portugal
#
#                                              category       date  \
# 0                        Serviços e consultoria de TI 2023-06-30
# 1                   Tecnologia, Informação e Internet 2023-06-09
# 2                         Desenvolvimento de software 2023-07-03
# 3                   Segurança de redes e computadores 2023-03-09
# 4   Serviços e consultoria de TI, Desenvolvimento ... 2023-06-19
# 5                              Recrutamento e seleção 2023-07-07
# 6                      Serviços de gestão estratégica 2023-06-08
# 7   Serviços e consultoria de TI, Desenvolvimento ... 2023-06-19
# 8                        Serviços e consultoria de TI 2023-06-05
# 9                                                 N/A 2023-02-21
# 10                             Recrutamento e seleção 2023-06-14
# 11                       Serviços e consultoria de TI 2023-07-07
# 12                Tecnologia da informação e serviços 2023-06-03
# 13                       Serviços e consultoria de TI 2023-06-21
# 14                             Recrutamento e seleção 2023-06-14
# 15                       Serviços e consultoria de TI 2023-06-28
# 16                       Serviços e consultoria de TI 2023-07-06
# 17                             Recrutamento e seleção 2023-06-14
# 18    Fabricação de aparelhos elétricos e eletrônicos 2023-04-19
# 19                             Recrutamento e seleção 2023-06-14
#
#                                                skills  \
# 0   SQL,PHP,Artificial Intelligence,Grafana,Tablea...
# 1   Scrum,DevOps,Scala,Fintech,AWS,Data Engineerin...
# 2      Python,Kotlin,Natural Language Processing,Java
# 3   Cybersecurity,Security Testing,Django,Informat...
# 4   Data Pipelines,Docker,Django,Data Privacy,Ansi...
# 5   Docker,Data Science,AWS,CI/CD,Python,Kubernete...
# 6                   Python,Docker,CI/CD,Microservices
# 7   Data Pipelines,Docker,Django,Data Privacy,Ansi...
# 8                                       Python,DevOps
# 9                                 PHP,Go,R,Python,SQL
# 10  Docker,Scrum,PostgreSQL,AWS,Django,Flask,E-com...
# 11  Docker,Scrum,Data Integration,PostgreSQL,Git,C...
# 12  Microservices,Docker,Scrum,Android,Git,Flask,B...
# 13                    Python,Perl,SQL,Shell Scripting
# 14  Docker,Scrum,PostgreSQL,AWS,Django,Flask,E-com...
# 15  Data Pipelines,Docker,DevOps,Data Science,Data...
# 16         PostgreSQL,SQL,Django,Flask,Python,MongoDB
# 17  Docker,Scrum,PostgreSQL,AWS,Django,Flask,E-com...
# 18  Cybersecurity,Big Data,Terraform,Git,Jenkins,I...
# 19  Docker,Scrum,PostgreSQL,AWS,Django,Flask,E-com...
#
#                                                  link       city   country
# 0   https://pt.linkedin.com/jobs/view/data-analyst...     Lisbon  Portugal
# 1   https://pt.linkedin.com/jobs/view/backend-engi...      Porto  Portugal
# 2   https://pt.linkedin.com/jobs/view/senior-softw...     Lisbon  Portugal
# 3   https://pt.linkedin.com/jobs/view/django-backe...     Lisbon  Portugal
# 4   https://pt.linkedin.com/jobs/view/software-eng...             Portugal
# 5   https://pt.linkedin.com/jobs/view/senior-pytho...     Lisbon  Portugal
# 6   https://pt.linkedin.com/jobs/view/python-devel...     Lisbon  Portugal
# 7   https://pt.linkedin.com/jobs/view/software-eng...      Porto  Portugal
# 8   https://pt.linkedin.com/jobs/view/team-python-...      Porto  Portugal
# 9   https://pt.linkedin.com/jobs/view/data-scienti...     Lisbon  Portugal
# 10  https://pt.linkedin.com/jobs/view/python-devel...      Porto  Portugal
# 11  https://pt.linkedin.com/jobs/view/senior-pytho...     Lisbon  Portugal
# 12  https://pt.linkedin.com/jobs/view/python-devel...     Lisbon  Portugal
# 13  https://pt.linkedin.com/jobs/view/python-devel...     Lisbon  Portugal
# 14  https://pt.linkedin.com/jobs/view/python-devel...     Lisbon  Portugal
# 15  https://pt.linkedin.com/jobs/view/senior-full-...             Portugal
# 16  https://pt.linkedin.com/jobs/view/software-dev...     Lisbon  Portugal
# 17  https://pt.linkedin.com/jobs/view/python-devel...    Amadora  Portugal
# 18  https://pt.linkedin.com/jobs/view/python-engin...    Amadora  Portugal
# 19  https://pt.linkedin.com/jobs/view/python-devel...  Vila Real  Portugal

# %% [markdown]
# Save preprocessed data

# %%
import pickle


with open('processed_data.pkl', 'wb') as f:
    pickle.dump(df, f)
